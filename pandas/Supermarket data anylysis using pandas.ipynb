# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Supermarket data anylysis using pandas.ipynb',
#  'supermarkets.json']

# %%
import pandas as pd

# %%
df1 = pd.read_json('supermarkets.json')

# %%
df1.set_index('ID')
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df2 = df1.set_index("Address")

# %%
df2
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df2.loc[:,"Country"]
# Out:
# Address
# 3666 21st St       USA
# 735 Dolores St     USA
# 332 Hill St        USA
# 3995 23rd St       USA
# 1056 Sanchez St    USA
# 551 Alvarado St    USA
# Name: Country, dtype: object

# %%
list(df2.loc[:,"Country"])
# Out:
# ['USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df2.loc["735 Dolores St":,"Country":"Employees"]
# Out:
#                 Country         Name  Employees
# Address
# 735 Dolores St      USA  Bready Shop         15
# 332 Hill St         USA  Super River         25
# 3995 23rd St        USA   Ben's Shop         10
# 1056 Sanchez St     USA      Sanchez         12
# 551 Alvarado St     USA   Richvalley         20

# %%
df2.iloc[1:2,0:3]
# Out:
#                 ID           City     State
# Address
# 735 Dolores St   2  San Francisco  CA 94119

# %%
df2
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df2.drop('ID',1)
# Out:
# c:\users\nishi\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
#                           City             State Country         Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# ...

# %%
df2.drop('332 Hill St',0)
# Out:
# c:\users\nishi\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
#                  ID           City       State Country         Name  Employees
# Address
# 3666 21st St      1  San Francisco    CA 94114     USA      Madeira          8
# 735 Dolores St    2  San Francisco    CA 94119     USA  Bready Shop         15
# 3995 23rd St      4  San Francisco    CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St   5  San Francisco  California     USA      Sanchez         12
# 551 Alvarado St   6  San Francisco    CA 94114     USA   Richvalley         20

# %%
df2.drop(df2.columns[0:3],1)
# Out:
# c:\users\nishi\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
#                 Country         Name  Employees
# Address
# 3666 21st St        USA      Madeira          8
# 735 Dolores St      USA  Bready Shop         15
# 332 Hill St         USA  Super River         25
# 3995 23rd St        USA   Ben's Shop         10
# 1056 Sanchez St     USA      Sanchez         12
# 551 Alvarado St     USA   Richvalley         20

# %%
df2
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df2["New"]=df2.shape[0]* ["North America"]

# %%
df2=df2.drop("New",1)
# Out:
# c:\users\nishi\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
df2
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees      Continent
# Address
# 3666 21st St             8  North America
# 735 Dolores St          15  North America
# 332 Hill St             25  North America
# 3995 23rd St            10  North America
# 1056 Sanchez St         12  North America
# 551 Alvarado St         20  North America

# %%
df2["Continent"]=df2["Country"]+ " North America"

# %%
df2
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees          Continent
# Address
# 3666 21st St             8  USA North America
# 735 Dolores St          15  USA North America
# 332 Hill St             25  USA North America
# 3995 23rd St            10  USA North America
# 1056 Sanchez St         12  USA North America
# 551 Alvarado St         20  USA North America

# %%
df2_t=df2.T

# %%
df2_t
# Out:
# Address         3666 21st St     735 Dolores St        332 Hill St  \
# ID                         1                  2                  3
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114           CA 94119   California 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop        Super River
# Employees                  8                 15                 25
# Continent  USA North America  USA North America  USA North America
#
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St
# ID                         4                  5                  6
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114         California           CA 94114
# Country                  USA                USA                USA
# Name              Ben's Shop            Sanchez         Richvalley
# ...

# %%
df2_t["WelserStrasse"]=[7,"Nuremberg","Bavaria","Germany","Nishith",8,"Europe"]

# %%
df2_t
# Out:
# Address         3666 21st St     735 Dolores St        332 Hill St  \
# ID                         1                  2                  3
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114           CA 94119   California 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop        Super River
# Employees                  8                 15                 25
# Continent  USA North America  USA North America  USA North America
#
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St  \
# ID                         4                  5                  6
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114         California           CA 94114
# Country                  USA                USA                USA
# Name              Ben's Shop            Sanchez         Richvalley
# ...

# %%
df2=df2_t.T

# %%
df2
# Out:
#                 ID           City             State  Country         Name  \
# Address
# 3666 21st St     1  San Francisco          CA 94114      USA      Madeira
# 735 Dolores St   2  San Francisco          CA 94119      USA  Bready Shop
# 332 Hill St      3  San Francisco  California 94114      USA  Super River
# 3995 23rd St     4  San Francisco          CA 94114      USA   Ben's Shop
# 1056 Sanchez St  5  San Francisco        California      USA      Sanchez
# 551 Alvarado St  6  San Francisco          CA 94114      USA   Richvalley
# WelserStrasse    7      Nuremberg           Bavaria  Germany      Nishith
#
#                 Employees          Continent
# Address
# 3666 21st St            8  USA North America
# 735 Dolores St         15  USA North America
# 332 Hill St            25  USA North America
# 3995 23rd St           10  USA North America
# 1056 Sanchez St        12  USA North America
# 551 Alvarado St        20  USA North America
# ...

# %%
import geopy

# %%
from geopy.geocoders import Nominatim

# %%
nom= Nominatim(user_agent="Nishith")
nom.geocode("332 Hill St,San Francisco,California 94114,USA")
# Out:
# Location(332, Hill Street, Noe Valley, San Francisco, California, 94114, United States, (37.755836349999996, -122.42883158327517, 0.0))

# %%
df2
# Out:
#                 ID           City             State  Country         Name  \
# Address
# 3666 21st St     1  San Francisco          CA 94114      USA      Madeira
# 735 Dolores St   2  San Francisco          CA 94119      USA  Bready Shop
# 332 Hill St      3  San Francisco  California 94114      USA  Super River
# 3995 23rd St     4  San Francisco          CA 94114      USA   Ben's Shop
# 1056 Sanchez St  5  San Francisco        California      USA      Sanchez
# 551 Alvarado St  6  San Francisco          CA 94114      USA   Richvalley
# WelserStrasse    7      Nuremberg           Bavaria  Germany      Nishith
#
#                 Employees          Continent
# Address
# 3666 21st St            8  USA North America
# 735 Dolores St         15  USA North America
# 332 Hill St            25  USA North America
# 3995 23rd St           10  USA North America
# 1056 Sanchez St        12  USA North America
# 551 Alvarado St        20  USA North America
# ...

# %%
df1["Continent"] = df1["Country"]+","+ "North America"

# %%
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees          Continent
# 0          8  USA,North America
# 1         15  USA,North America
# 2         25  USA,North America
# 3         10  USA,North America
# 4         12  USA,North America
# 5         20  USA,North America

# %%
df1=df1.drop(["Address"],1)
# Out:
# c:\users\nishi\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
df1=df1.drop(["Addres"],1)
# Out:
# c:\users\nishi\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
df1["Coordinates"]=df1["Address"].apply(nom.geocode)

# %%
df1["Address"]=["3666 21st St","735 Dolores St","332 Hill St","3995 23rd St","1056 Sanchez St","551 Alvarado St"]

# %%
df1["Address"]=df1["Address"]+", "+df1["City"]+" ,"+df1["State"]+" ,"+df1["Country"]

# %%
df1
# Out:
#    ID           City             State Country         Name  Employees  \
# 0   1  San Francisco          CA 94114     USA      Madeira          8
# 1   2  San Francisco          CA 94119     USA  Bready Shop         15
# 2   3  San Francisco  California 94114     USA  Super River         25
# 3   4  San Francisco          CA 94114     USA   Ben's Shop         10
# 4   5  San Francisco        California     USA      Sanchez         12
# 5   6  San Francisco          CA 94114     USA   Richvalley         20
#
#            Continent Coordinates  \
# 0  USA,North America        None
# 1  USA,North America        None
# 2  USA,North America        None
# 3  USA,North America        None
# 4  USA,North America        None
# 5  USA,North America        None
#
#                                              Address
# 0         3666 21st St, San Francisco ,CA 94114 ,USA
# 1       735 Dolores St, San Francisco ,CA 94119 ,USA
# 2  332 Hill St, San Francisco ,California 94114 ,USA
# ...

# %%
df1["Coordinates"]=df1["Address"].apply(nom.geocode)

# %%
df1
# Out:
#    ID           City             State Country         Name  Employees  \
# 0   1  San Francisco          CA 94114     USA      Madeira          8
# 1   2  San Francisco          CA 94119     USA  Bready Shop         15
# 2   3  San Francisco  California 94114     USA  Super River         25
# 3   4  San Francisco          CA 94114     USA   Ben's Shop         10
# 4   5  San Francisco        California     USA      Sanchez         12
# 5   6  San Francisco          CA 94114     USA   Richvalley         20
#
#            Continent                                        Coordinates  \
# 0  USA,North America  (3666, 21st Street, Noe Valley, San Francisco,...
# 1  USA,North America  (735, Dolores Street, Duboce Triangle, San Fra...
# 2  USA,North America  (332, Hill Street, Noe Valley, San Francisco, ...
# 3  USA,North America  (3995, 23rd Street, Noe Valley, San Francisco,...
# 4  USA,North America  (1056;1058;1060;1062, Sanchez Street, Noe Vall...
# ...

# %%
df1["Latitude"]= df1["Coordinates"].apply(lambda x: x.latitude if x != None else None)

# %%
df1["Longitude"]= df1["Coordinates"].apply(lambda x: x.longitude if x != None else None)

# %%
df1
# Out:
#    ID           City             State Country         Name  Employees  \
# 0   1  San Francisco          CA 94114     USA      Madeira          8
# 1   2  San Francisco          CA 94119     USA  Bready Shop         15
# 2   3  San Francisco  California 94114     USA  Super River         25
# 3   4  San Francisco          CA 94114     USA   Ben's Shop         10
# 4   5  San Francisco        California     USA      Sanchez         12
# 5   6  San Francisco          CA 94114     USA   Richvalley         20
#
#            Continent                                        Coordinates  \
# 0  USA,North America  (3666, 21st Street, Noe Valley, San Francisco,...
# 1  USA,North America  (735, Dolores Street, Duboce Triangle, San Fra...
# 2  USA,North America  (332, Hill Street, Noe Valley, San Francisco, ...
# 3  USA,North America  (3995, 23rd Street, Noe Valley, San Francisco,...
# 4  USA,North America  (1056;1058;1060;1062, Sanchez Street, Noe Vall...
# ...
